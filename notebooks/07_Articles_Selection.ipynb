# %%
import pandas as pd

# %%
data = pd.read_csv(r'D:\0_Respaldo\000_KaggleX\Projects\Rag-Ley675\675_LAW\data\clean\articulos.csv')

# %%
data.head(1)
# Out:
#    articulo_id articulo_name detalla  \
# 0            1    Artículo 1  Objeto
#
#                                            contenido
# 0  La presente ley regula la forma especial de do...

# %%
df = data.copy()

# %%
df.tail(5)
# Out:
#     articulo_id articulo_name  \
# 79           82   Artículo 82
# 80           83   Artículo 83
# 81           84   Artículo 84
# 82           85   Artículo 85
# 83           87   Artículo 87
#
#                                               detalla  \
# 79  Obligaciones de mantenimiento, reparación y me...
# 80                Impuesto de renta y complementarios
# 81  Las disposiciones contempladas en el presente ...
# 82                                        Parcelación
# 83                             Vigencia y derogatoria
#
#                                             contenido
# 79  Las Unidades Inmobiliarias Cerradas tendrán a ...
# 80  Las unidades Inmobiliarias Cerradas son person...
# 81                                                NaN
# 82  Cuando una parcelación esté conformada por lot...
# 83  La presente ley rige a partir de su publicació...

# %%
df['contenido'] = df['contenido'].astype(str)

# %%
df['conteo_palabras'] = df['contenido'].str.split().apply(len)

# %%
df['conteo_palabras'].describe()
# Out:
# count     84.000000
# mean     167.964286
# std      150.379315
# min        1.000000
# 25%       69.000000
# 50%      132.000000
# 75%      216.250000
# max      910.000000
# Name: conteo_palabras, dtype: float64

# %%
# Definir los rangos para agrupar el conteo de palabras
bins = [0, 132, 216, 910]  # Puedes ajustar estos valores
labels = ['0-132', '131-216', '217-910']

# %%
# Crear la columna de rangos etáreos
df['rango_palabras'] = pd.cut(df['conteo_palabras'], bins=bins, labels=labels, right=True)

# %%
df.sample(5)
# Out:
#     articulo_id articulo_name                                        detalla  \
# 77           80   Artículo 80  Cobro de los servicios públicos domiciliarios
# 21           22   Artículo 22                Bienes comunes de uso exclusivo
# 60           63   Artículo 63                Unidades Inmobiliarias Cerradas
# 56           58   Artículo 58                         Solución de conflictos
# 50           52   Artículo 52                     Administración provisional
#
#                                             contenido  conteo_palabras  \
# 77  Los urbanizadores y constructores de Unidades ...               75
# 21  Los bienes comunes no necesarios para el disfr...              174
# 60  Las  son conjuntos de edificios, casas y demás...               69
# 56  Para la solución de los conflictos que se pres...              332
# 50  Mientras el órgano competente no elija al admi...              125
#
#    rango_palabras
# 77          0-132
# 21        131-216
# ...

# %%
# Filtrar las filas que se encuentran en el rango '0-50'
df_rango_0_132 = df[df['rango_palabras'] == '0-132']

# %%
df_rango_131_216 = df[df['rango_palabras'] == '131-216']

# %%
df_rango_0_132
# Out:
#     articulo_id articulo_name  \
# 3             4    Artículo 4
# 5             6    Artículo 6
# 9            10   Artículo 10
# 11           12   Artículo 12
# 14           15   Artículo 15
# 25           25   Artículo 25
# 26           26   Artículo 26
# 27           27   Artículo 27
# 30           30   Artículo 30
# 32           33   Artículo 33
# 33           34   Artículo 34
# 35           36   Artículo 36
# 39           40   Artículo 40
# 40           41   Artículo 41
# 50           52   Artículo 52
# 52           54   Artículo 54
# 53           55   Artículo 55
# 55           57   Artículo 57
# 58           60   Artículo 60
# 60           63   Artículo 63
# 62           65   Artículo 65
# 63           66   Artículo 66
# 64           67   Artículo 67
# 65           68   Artículo 68
# 66           69   Artículo 69
# 67           70   Artículo 70
# 68           71   Artículo 71
# 69           72   Artículo 72
# 70           73   Artículo 73
# 71           74   Artículo 74
# ...

# %%
df_rango_217_910 = df[df['rango_palabras'] == '217-910']

# %%
df_rango_0_132.to_csv('articulos_0-132.csv', index=False)

# %%
df_rango_131_216
# Out:
#     articulo_id articulo_name  \
# 0             1    Artículo 1
# 1             2    Artículo 2
# 6             7    Artículo 7
# 7             8    Artículo 8
# 8             9    Artículo 9
# 10           11   Artículo 11
# 12           13   Artículo 13
# 13           14   Artículo 14
# 15           16   Artículo 16
# 16           17   Artículo 17
# 20           21   Artículo 21
# 21           22   Artículo 22
# 22           23   Artículo 23
# 28           28   Artículo 28
# 31           31   Artículo 31
# 34           35   Artículo 35
# 43           44   Artículo 44
# 47           48   Artículo 48
# 54           56   Artículo 56
# 59           62   Artículo 62
# 61           64   Artículo 64
#
#                                               detalla  \
# 0                                              Objeto
# 1                   Principios orientadores de la ley
# 6                     Conjuntos integrados por etapas
# 7   Certificación sobre existencia y representació...
# ...

# %%
df_rango_131_216.to_csv('articulos_133-216.csv', index=False)

# %%
df_rango_131_216
# Out:
#     articulo_id articulo_name  \
# 0             1    Artículo 1
# 1             2    Artículo 2
# 6             7    Artículo 7
# 7             8    Artículo 8
# 8             9    Artículo 9
# 10           11   Artículo 11
# 12           13   Artículo 13
# 13           14   Artículo 14
# 15           16   Artículo 16
# 16           17   Artículo 17
# 20           21   Artículo 21
# 21           22   Artículo 22
# 22           23   Artículo 23
# 28           28   Artículo 28
# 31           31   Artículo 31
# 34           35   Artículo 35
# 43           44   Artículo 44
# 47           48   Artículo 48
# 54           56   Artículo 56
# 59           62   Artículo 62
# 61           64   Artículo 64
#
#                                               detalla  \
# 0                                              Objeto
# 1                   Principios orientadores de la ley
# 6                     Conjuntos integrados por etapas
# 7   Certificación sobre existencia y representació...
# ...

# %%
df_rango_217_910
# Out:
#     articulo_id articulo_name  \
# 2             3    Artículo 3
# 4             5    Artículo 5
# 17           18   Artículo 18
# 18           19   Artículo 19
# 19           20   Artículo 20
# 23           24   Artículo 24
# 24           25   Artículo 25
# 29           29   Artículo 29
# 36           37   Artículo 37
# 37           38   Artículo 38
# 38           39   Artículo 39
# 41           42   Artículo 42
# 42           43   Artículo 43
# 44           45   Artículo 45
# 45           46   Artículo 46
# 46           47   Artículo 47
# 48           49   Artículo 49
# 49           51   Artículo 51
# 51           53   Artículo 53
# 56           58   Artículo 58
# 57           59   Artículo 59
#
#                                               detalla  \
# 2   Reglamentado por el Decreto Nacional 1060 de 2009
# 4   Contenido de la escritura o reglamento de prop...
# 17  Obligaciones de los propietarios respecto de l...
# 18  Reglamentado por el Decreto Nacional 1060 de 2009
# ...

# %%
df_rango_217_910.to_csv('articulos_217-910.csv', index=False, encoding='Lating-1')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 df_rango_217_910.to_csv('articulos_217-910.csv', index=False, encoding='Lating-1')
#
# File d:\0_Respaldo\000_KaggleX\Projects\Rag-Ley675\675_LAW\.venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
df_rango_217_910
# Out:
#     articulo_id articulo_name  \
# 2             3    Artículo 3
# 4             5    Artículo 5
# 17           18   Artículo 18
# 18           19   Artículo 19
# 19           20   Artículo 20
# 23           24   Artículo 24
# 24           25   Artículo 25
# 29           29   Artículo 29
# 36           37   Artículo 37
# 37           38   Artículo 38
# 38           39   Artículo 39
# 41           42   Artículo 42
# 42           43   Artículo 43
# 44           45   Artículo 45
# 45           46   Artículo 46
# 46           47   Artículo 47
# 48           49   Artículo 49
# 49           51   Artículo 51
# 51           53   Artículo 53
# 56           58   Artículo 58
# 57           59   Artículo 59
#
#                                               detalla  \
# 2   Reglamentado por el Decreto Nacional 1060 de 2009
# 4   Contenido de la escritura o reglamento de prop...
# 17  Obligaciones de los propietarios respecto de l...
# 18  Reglamentado por el Decreto Nacional 1060 de 2009
# ...
