# %%
import pandas as pd

# %%
data = pd.read_csv(r'D:\0_Respaldo\000_KaggleX\Projects\Rag-Ley675\675_LAW\data\clean\q-0-132.csv', encoding='latin-1')
data2 = pd.read_csv(r'D:\0_Respaldo\000_KaggleX\Projects\Rag-Ley675\675_LAW\data\clean\q-133-216.csv', encoding='latin-1')
data3 = pd.read_csv(r'D:\0_Respaldo\000_KaggleX\Projects\Rag-Ley675\675_LAW\data\clean\q-217-910.csv', encoding='latin-1')

# %%
data.head(13)
# Out:
#     pregunta_id                                           pregunta  \
# 0          7301  ¿Quién tiene la potestad para decidir sobre la...
# 1          7302  ¿Qué tipo de mayoría se requiere en la Asamble...
# 2          7303  ¿Qué tipo de autoridad competente debe aprobar...
# 3          7304  ¿Cuáles son los pasos específicos que se deben...
# 4          7305  ¿Existe un plazo específico para que la autori...
# 5          7306  ¿A qué áreas específicas se aplica la decisión...
# 6          7307  ¿Se pueden aplicar diferentes cánones arquitec...
# 7          7308  ¿Qué tipo de cambios se consideran "adopción" ...
# 8          7309  ¿Existen ejemplos específicos de cambios que p...
# 9          7310  ¿Qué tipo de impacto puede tener la adopción o...
# 10         7311  ¿Existen mecanismos para que los copropietario...
# 11         7312  ¿Qué tipo de sanciones se pueden aplicar a los...
# 12         7313  ¿Qué se entiende por "cánones arquitectónicos ...
#
#     pregunta_name  articulo_id  embeding
# 0   pregunta 7301           73       NaN
# 1   pregunta 7302           73       NaN
# 2   pregunta 7303           73       NaN
# 3   pregunta 7304           73       NaN
# 4   pregunta 7305           73       NaN
# 5   pregunta 7306           73       NaN
# 6   pregunta 7307           73       NaN
# 7   pregunta 7308           73       NaN
# 8   pregunta 7309           73       NaN
# 9   pregunta 7310           73       NaN
# 10  pregunta 7311           73       NaN
# 11  pregunta 7312           73       NaN
# 12  pregunta 7313           73       NaN

# %%
data2.tail(4)
# Out:
#      pregunta_id                                           pregunta  \
# 322         6418  ¿Qué tipo de responsabilidades tienen los prop...
# 323         6419                         ¿Cómo se gestiona una UIC?
# 324         6420  ¿Qué tipo de conflictos pueden surgir en relac...
# 325         6421  ¿Qué legislación actual regula las UIC en Colo...
#
#      pregunta_name  articulo_id  embeding
# 322  pregunta 6418           64       NaN
# 323  pregunta 6419           64       NaN
# 324  pregunta 6420           64       NaN
# 325  pregunta 6421           64       NaN

# %%
data3.head(4)
# Out:
#    pregunta_id                                           pregunta  \
# 0          301  ¿Qué es el Régimen de Propiedad Horizontal y c...
# 1          302  ¿Qué tipo de construcciones se pueden someter ...
# 2          303  ¿Cuáles son las diferencias entre un edificio ...
# 3          304  ¿Qué tipo de normatividad regula el Régimen de...
#
#   pregunta_name  articulo_id  embeding
# 0  pregunta 301            3       NaN
# 1  pregunta 302            3       NaN
# 2  pregunta 303            3       NaN
# 3  pregunta 304            3       NaN

# %%
df = pd.concat([data,data2], ignore_index=True)

# %%
df
# Out:
#      pregunta_id                                           pregunta  \
# 0           7301  ¿Quién tiene la potestad para decidir sobre la...
# 1           7302  ¿Qué tipo de mayoría se requiere en la Asamble...
# 2           7303  ¿Qué tipo de autoridad competente debe aprobar...
# 3           7304  ¿Cuáles son los pasos específicos que se deben...
# 4           7305  ¿Existe un plazo específico para que la autori...
# ..           ...                                                ...
# 949         6417  ¿Cuáles son los inconvenientes de constituir u...
# 950         6418  ¿Qué tipo de responsabilidades tienen los prop...
# 951         6419                         ¿Cómo se gestiona una UIC?
# 952         6420  ¿Qué tipo de conflictos pueden surgir en relac...
# 953         6421  ¿Qué legislación actual regula las UIC en Colo...
#
#      pregunta_name  articulo_id  embeding
# 0    pregunta 7301           73       NaN
# 1    pregunta 7302           73       NaN
# 2    pregunta 7303           73       NaN
# 3    pregunta 7304           73       NaN
# 4    pregunta 7305           73       NaN
# ..             ...          ...       ...
# 949  pregunta 6417           64       NaN
# 950  pregunta 6418           64       NaN
# 951  pregunta 6419           64       NaN
# 952  pregunta 6420           64       NaN
# 953  pregunta 6421           64       NaN
#
# [954 rows x 5 columns]

# %%
df = pd.concat([df,data3], ignore_index=True)

# %%
df_o = df.sort_values(by='articulo_id', ascending=True)

# %%
df_o
# Out:
#      pregunta_id                                           pregunta  \
# 645          118  ¿Existen mecanismos para la protección de los ...
# 628          101  ¿Qué es la propiedad horizontal y cómo se defi...
# 630          103  ¿Cuál es el objetivo principal de la ley que r...
# 631          104  ¿Cómo se garantiza la seguridad y la convivenc...
# 632          105  ¿Cómo se relaciona la propiedad horizontal con...
# ..           ...                                                ...
# 204         8703  ¿Se especifica la fecha exacta de publicación ...
# 203         8702       ¿Qué significa "a partir de su publicación"?
# 202         8701            ¿Cuándo entra en vigor la presente ley?
# 210         8709  ¿Qué sucede con las normas que se hayan emitid...
# 206         8705    ¿Cuáles son los números de las leyes derogadas?
#
#      pregunta_name  articulo_id  embeding
# 645   pregunta 118            1       NaN
# 628   pregunta 101            1       NaN
# 630   pregunta 103            1       NaN
# 631   pregunta 104            1       NaN
# 632   pregunta 105            1       NaN
# ..             ...          ...       ...
# 204  pregunta 8703           87       NaN
# 203  pregunta 8702           87       NaN
# 202  pregunta 8701           87       NaN
# 210  pregunta 8709           87       NaN
# 206  pregunta 8705           87       NaN
#
# [1389 rows x 5 columns]

# %%
df1 = df_o[['pregunta_id', 'articulo_id']]

# %%
df1['responde'] = 'Hacia articulo'
# Out:
# C:\Users\USUARIO\AppData\Local\Temp\ipykernel_5976\2089896600.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['responde'] = 'Hacia articulo'

# %%
df1
# Out:
#      pregunta_id  articulo_id        responde
# 645          118            1  Hacia articulo
# 628          101            1  Hacia articulo
# 630          103            1  Hacia articulo
# 631          104            1  Hacia articulo
# 632          105            1  Hacia articulo
# ..           ...          ...             ...
# 204         8703           87  Hacia articulo
# 203         8702           87  Hacia articulo
# 202         8701           87  Hacia articulo
# 210         8709           87  Hacia articulo
# 206         8705           87  Hacia articulo
#
# [1389 rows x 3 columns]

# %%
df1.to_csv('preguntas_articulos_enlace.csv', index=False)

# %% [markdown]
# ### Crear nodo

# %%
df.to_csv(r'D:\0_Respaldo\000_KaggleX\Projects\Rag-Ley675\675_LAW\notebooks\preguntas_articulos_nodos.csv', index=False)
